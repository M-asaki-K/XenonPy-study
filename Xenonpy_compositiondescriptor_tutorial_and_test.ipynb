# %%
from xenonpy.datatools import preset

# %%
preset.build('mp_samples', api_key='TxlbOdzj8Q6LhpkCB')
# Out:
# 100%|██████████| 10/10 [00:16<00:00,  1.66s/it]

# %%
from xenonpy.datatools import Dataset

# %%
dataset = Dataset('/set1', '/set2')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-2d8db46df156> in <module>
# ----> 1 dataset = Dataset('/set1', '/set2')
#
# ~/anaconda3/envs/xenonpy/lib/python3.7/site-packages/xenonpy/datatools/dataset.py in __init__(self, backend, prefix, *paths)
#      38         self._prefix = prefix
#      39
# ---> 40         self._make_index(prefix=prefix)
#      41
#      42     def _make_index(self, *, prefix):
#
# ~/anaconda3/envs/xenonpy/lib/python3.7/site-packages/xenonpy/datatools/dataset.py in _make_index(self, prefix)
#      72             path = Path(path).expanduser().absolute()
#      73             if not path.exists():
# ---> 74                 raise RuntimeError('%s not exists' % str(path))
#      75             make(path)
#      76
#
# RuntimeError: /set1 not exists

# %%
from xenonpy.datatools import preset
preset.sync('elements')
preset.sync('elements_completed')
# Out:
# fetching dataset `elements` from https://github.com/yoshida-lab/dataset/releases/download/v0.1.3/elements.pd.xz.
# fetching dataset `elements_completed` from https://github.com/yoshida-lab/dataset/releases/download/v0.1.3/elements_completed.pd.xz.

# %%
from xenonpy.descriptor import Compositions
cal = Compositions()
cal
# Out:
# Compositions:
#   |- composition:
#   |  |- Counting
#   |  |- WeightedAverage
#   |  |- WeightedSum
#   |  |- WeightedVariance
#   |  |- GeometricMean
#   |  |- HarmonicMean
#   |  |- MaxPooling
#   |  |- MinPooling

# %%
from xenonpy.datatools import preset
samples = preset.mp_samples
samples.head()
# Out:
#             band_gap                       composition    density  \
# mp-1008807    0.0000  {'Rb': 1.0, 'Cu': 1.0, 'O': 1.0}   4.693790
# mp-1009640    0.0000             {'Pr': 1.0, 'N': 1.0}   8.145777
# mp-1016825    0.7867  {'Hf': 1.0, 'Mg': 1.0, 'O': 3.0}   6.165888
# mp-1017582    0.0000  {'La': 1.0, 'Pt': 3.0, 'C': 1.0}  14.284261
# mp-1021511    1.5186             {'Cd': 1.0, 'S': 1.0}   2.582691
#
#             e_above_hull   efermi     elements  final_energy_per_atom  \
# mp-1008807      0.996645  1.10062  [Rb, Cu, O]              -3.302398
# mp-1009640      0.759393  5.21767      [Pr, N]              -7.082624
# mp-1016825      0.589550  2.42457  [Hf, Mg, O]              -7.911723
# mp-1017582      0.519116   8.1605  [La, Pt, C]              -6.684482
# mp-1021511      0.252860 -2.12118      [Cd, S]              -2.909105
#
#             formation_energy_per_atom pretty_formula  \
# mp-1008807                  -0.188318          RbCuO
# mp-1009640                  -0.714548            PrN
# mp-1016825                  -3.064161         HfMgO3
# mp-1017582                  -0.219971         LaPt3C
# mp-1021511                  -0.719529            CdS
#
#                                                     structure     volume
# mp-1008807  [[ 3.07896472  3.07896472 -3.07896472] Rb, [0....  58.377317
# mp-1009640  [[0. 0. 0.] Pr, [1.57925232 1.57925232 1.58276...  31.579717
# mp-1016825  [[2.03622802 2.03622802 2.03622802] Hf, [0. 0....  67.541269
# mp-1017582  [[0. 0. 0.] La, [0.         2.20339716 2.20339...  85.579224
# mp-1021511  [[2.12807605 1.22864286 2.67990375] Cd, [-2.46...  92.890725

# %%
comps = samples['composition']
descriptor = cal.transform(comps)
descriptor.head()
# Out:
#             ave:atomic_number  ave:atomic_radius  ave:atomic_radius_rahm  \
# mp-1008807          24.666667         174.067140              209.333333
# mp-1009640          33.000000         137.000000              232.500000
# mp-1016825          21.600000         153.120852              203.400000
# mp-1017582          59.400000         139.000000              232.800000
# mp-1021511          32.000000         140.500000              226.000000
#
#             ave:atomic_volume  ave:atomic_weight  ave:boiling_point  \
# mp-1008807          25.666667          55.004267        1297.063333
# mp-1009640          19.050000          77.457330        1931.200000
# mp-1016825          13.920000          50.158400        1420.714000
# mp-1017582          11.020000         147.233694        4226.000000
# mp-1021511          14.300000          72.237000         877.912000
#
#             ave:bulk_modulus  ave:c6_gb  ave:covalent_radius_cordero  \
# mp-1008807         72.868680    1646.90                   139.333333
# mp-1009640         43.182441    1892.85                   137.000000
# mp-1016825         76.663625     343.82                   102.800000
# mp-1017582        150.200000    1037.58                   137.600000
# mp-1021511         24.850000     272.50                   124.500000
#
#             ave:covalent_radius_pyykko  ...  min:num_s_valence  min:period  \
# mp-1008807                  128.333333  ...                1.0         2.0
# mp-1009640                  123.500000  ...                2.0         2.0
# mp-1016825                   96.000000  ...                2.0         2.0
# mp-1017582                  124.800000  ...                1.0         2.0
# mp-1021511                  119.500000  ...                2.0         3.0
#
#             min:specific_heat  min:thermal_conductivity  min:vdw_radius  \
# mp-1008807              0.360                   0.02658           152.0
# mp-1009640              0.192                   0.02583           155.0
# mp-1016825              0.146                   0.02658           152.0
# mp-1017582              0.133                  13.00000           170.0
# mp-1021511              0.232                   0.20500           180.0
#
#             min:vdw_radius_alvarez  min:vdw_radius_mm3  min:vdw_radius_uff  \
# mp-1008807                   150.0               182.0               349.5
# mp-1009640                   166.0               193.0               360.6
# mp-1016825                   150.0               182.0               302.1
# mp-1017582                   177.0               204.0               275.4
# mp-1021511                   189.0               215.0               284.8
#
#             min:sound_velocity  min:Polarizability
# mp-1008807               317.5               0.802
# mp-1009640               333.6               1.100
# mp-1016825               317.5               0.802
# mp-1017582              2475.0               1.670
# mp-1021511              2310.0               2.900
#
# [5 rows x 290 columns]

# %%
import pandas as pd
dfrev = pd.read_csv('MPcompwithcomposition.csv', index_col = 0)

# %%
compsrev = dfrev['composition']
descriptorrev = cal.transform(dfrev)
descriptorrev
# Out:
#             ave:atomic_number  ave:atomic_radius  ave:atomic_radius_rahm  \
# mp-1056                   NaN                NaN                     NaN
# mp-560190                 NaN                NaN                     NaN
# mp-753746                 NaN                NaN                     NaN
# mp-1605                   NaN                NaN                     NaN
# mp-1959                   NaN                NaN                     NaN
# ...                       ...                ...                     ...
# mp-27273                  NaN                NaN                     NaN
# mp-716052                 NaN                NaN                     NaN
# mp-600053                 NaN                NaN                     NaN
# mp-32715                  NaN                NaN                     NaN
# mp-1101405                NaN                NaN                     NaN
#
#             ave:atomic_volume  ave:atomic_weight  ave:boiling_point  \
# mp-1056                   NaN                NaN                NaN
# mp-560190                 NaN                NaN                NaN
# mp-753746                 NaN                NaN                NaN
# mp-1605                   NaN                NaN                NaN
# mp-1959                   NaN                NaN                NaN
# ...                       ...                ...                ...
# mp-27273                  NaN                NaN                NaN
# mp-716052                 NaN                NaN                NaN
# mp-600053                 NaN                NaN                NaN
# mp-32715                  NaN                NaN                NaN
# mp-1101405                NaN                NaN                NaN
#
#             ave:bulk_modulus  ave:c6_gb  ave:covalent_radius_cordero  \
# mp-1056                  NaN        NaN                          NaN
# mp-560190                NaN        NaN                          NaN
# mp-753746                NaN        NaN                          NaN
# mp-1605                  NaN        NaN                          NaN
# mp-1959                  NaN        NaN                          NaN
# ...                      ...        ...                          ...
# mp-27273                 NaN        NaN                          NaN
# mp-716052                NaN        NaN                          NaN
# mp-600053                NaN        NaN                          NaN
# mp-32715                 NaN        NaN                          NaN
# mp-1101405               NaN        NaN                          NaN
#
#             ave:covalent_radius_pyykko  ...  min:num_s_valence  min:period  \
# mp-1056                            NaN  ...                NaN         NaN
# mp-560190                          NaN  ...                NaN         NaN
# mp-753746                          NaN  ...                NaN         NaN
# mp-1605                            NaN  ...                NaN         NaN
# mp-1959                            NaN  ...                NaN         NaN
# ...                                ...  ...                ...         ...
# mp-27273                           NaN  ...                NaN         NaN
# mp-716052                          NaN  ...                NaN         NaN
# mp-600053                          NaN  ...                NaN         NaN
# mp-32715                           NaN  ...                NaN         NaN
# mp-1101405                         NaN  ...                NaN         NaN
#
#             min:specific_heat  min:thermal_conductivity  min:vdw_radius  \
# mp-1056                   NaN                       NaN             NaN
# mp-560190                 NaN                       NaN             NaN
# mp-753746                 NaN                       NaN             NaN
# mp-1605                   NaN                       NaN             NaN
# mp-1959                   NaN                       NaN             NaN
# ...                       ...                       ...             ...
# mp-27273                  NaN                       NaN             NaN
# mp-716052                 NaN                       NaN             NaN
# mp-600053                 NaN                       NaN             NaN
# mp-32715                  NaN                       NaN             NaN
# mp-1101405                NaN                       NaN             NaN
#
#             min:vdw_radius_alvarez  min:vdw_radius_mm3  min:vdw_radius_uff  \
# mp-1056                        NaN                 NaN                 NaN
# mp-560190                      NaN                 NaN                 NaN
# mp-753746                      NaN                 NaN                 NaN
# mp-1605                        NaN                 NaN                 NaN
# mp-1959                        NaN                 NaN                 NaN
# ...                            ...                 ...                 ...
# mp-27273                       NaN                 NaN                 NaN
# mp-716052                      NaN                 NaN                 NaN
# mp-600053                      NaN                 NaN                 NaN
# mp-32715                       NaN                 NaN                 NaN
# mp-1101405                     NaN                 NaN                 NaN
#
#             min:sound_velocity  min:Polarizability
# mp-1056                    NaN                 NaN
# mp-560190                  NaN                 NaN
# mp-753746                  NaN                 NaN
# mp-1605                    NaN                 NaN
# mp-1959                    NaN                 NaN
# ...                        ...                 ...
# mp-27273                   NaN                 NaN
# mp-716052                  NaN                 NaN
# mp-600053                  NaN                 NaN
# mp-32715                   NaN                 NaN
# mp-1101405                 NaN                 NaN
#
# [500 rows x 290 columns]

# %%
compsrev
# Out:
# mp-1056        {'Tb': 2.0, 'O': 3.0}
# mp-560190     {'Mo': 8.0, 'O': 23.0}
# mp-753746      {'Rb': 2.0, 'O': 1.0}
# mp-1605        {'Ag': 3.0, 'O': 4.0}
# mp-1959        {'Pu': 1.0, 'O': 2.0}
#                        ...
# mp-27273      {'Ti': 9.0, 'O': 17.0}
# mp-716052      {'Fe': 3.0, 'O': 4.0}
# mp-600053      {'Si': 1.0, 'O': 2.0}
# mp-32715       {'B': 36.0, 'O': 5.0}
# mp-1101405     {'Rb': 2.0, 'O': 1.0}
# Name: composition, Length: 500, dtype: object

# %%
comps = samples['composition']
comps
# Out:
# mp-1008807                {'Rb': 1.0, 'Cu': 1.0, 'O': 1.0}
# mp-1009640                           {'Pr': 1.0, 'N': 1.0}
# mp-1016825                {'Hf': 1.0, 'Mg': 1.0, 'O': 3.0}
# mp-1017582                {'La': 1.0, 'Pt': 3.0, 'C': 1.0}
# mp-1021511                           {'Cd': 1.0, 'S': 1.0}
#                                   ...
# mvc-2649      {'Mg': 4.0, 'Ta': 4.0, 'Mn': 2.0, 'O': 16.0}
# mvc-4727                 {'Ca': 4.0, 'Te': 2.0, 'O': 10.0}
# mvc-6767        {'Zn': 2.0, 'Ni': 1.0, 'W': 1.0, 'O': 6.0}
# mvc-6973                 {'Cu': 6.0, 'W': 12.0, 'O': 42.0}
# mvc-89        {'Ca': 4.0, 'Nb': 4.0, 'Cu': 2.0, 'O': 16.0}
# Name: composition, Length: 812, dtype: object
